# %%
import sys
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"


import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates  # For formatting x-axis with years
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
import tensorflow as tf
from keras.api.models import Sequential
from keras.api.layers import *
from keras.api.optimizers import Adam
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping

# %%
def load_data(ticker, start, end):
    data = yf.download(ticker, start=start, end=end, auto_adjust=False)

    if data.empty:
        print(f"Error: No data retrieved for {ticker}. Check API availability.")
        sys.exit(1)  # Stop the script if data is missing

    data.reset_index(inplace=True)
    return data
def create_sequences(X, y, dates, time_steps):
    X_seq, y_seq, date_seq = [], [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
        date_seq.append(dates[i + time_steps])  # Store corresponding date
    return np.array(X_seq), np.array(y_seq), np.array(date_seq)

# %%
def prepare_data(main_ticker, tickers, start_date, end_date):
    """
    Loads financial data from Yahoo Finance, calculates technical indicators,
    and prepares the dataset for modeling.

    Parameters:
        main_ticker (str): The main stock/index ticker (e.g., "^GSPC").
        tickers (list of str): List of additional tickers (e.g., ["AAPL", "MSFT", ...]).
        start_date (str): Start date for data collection (YYYY-MM-DD).
        end_date (str): End date for data collection (YYYY-MM-DD).

    Returns:
        pd.DataFrame: Processed dataset with selected tickers, technical indicators, and the target variable.
    """
    # Load data for additional tickers
    data = load_data(tickers, start_date, end_date)

    # Load data for the main ticker (^GSPC)
    main_data = load_data(main_ticker, start_date, end_date)

    # Create target variable (shifted Adj Close to predict next day's price)
    main_data["Target"] = main_data["Adj Close"].shift(-1)

    # Extract only the Adj Close prices of the selected tickers
    data_adj_close = data["Adj Close"]

    # Merge additional tickers' Adj Close into main_data
    for ticker in tickers:
        main_data[ticker] = data_adj_close[ticker]


    # --- Technical Indicators ---

    # Simple Moving Averages (SMA)
    main_data['SMA10'] = main_data['Adj Close'].rolling(window=10).mean()
    main_data['SMA50'] = main_data['Adj Close'].rolling(window=50).mean()


    delta = main_data['Adj Close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=14, min_periods=14).mean()
    avg_loss = loss.rolling(window=14, min_periods=14).mean()
    rs = avg_gain / avg_loss
    main_data['RSI'] = 100 - (100 / (1 + rs))

    main_data['EMA12'] = main_data['Adj Close'].ewm(span=12, adjust=False).mean()
    main_data['EMA26'] = main_data['Adj Close'].ewm(span=26, adjust=False).mean()
    main_data['MACD'] = main_data['EMA12'] - main_data['EMA26']

    main_data['Returns'] = main_data['Adj Close'].pct_change()
    main_data['Volatility'] = main_data['Returns'].rolling(window=20).std()

    main_data.dropna(inplace=True)

    return main_data

# %%
def select_top_features_rfe(data, n_features, target_column_contains="Adj Close", test_size=0.2, random_state=42):
    """
    Normalizes the data and performs RFE to select the top features.

    Parameters:
    - data: pandas DataFrame returned by prepare_data(...)
    - target_column_contains: string to identify target column (default "Adj Close")
    - n_features: number of top features to select (default 10)
    - test_size: fraction of data to use for testing (default 0.2)
    - random_state: seed for reproducibility

    Returns:
    - selected_features: list of selected feature names
    """

    # Flatten MultiIndex columns if needed
    if isinstance(data.columns, pd.MultiIndex):
        data.columns = ['_'.join(col).strip() for col in data.columns.values]

    # Find target column
    target_col = next((col for col in data.columns if target_column_contains in col), None)
    if not target_col:
        raise KeyError(f"Could not find target column containing '{target_column_contains}'.")

    # Prepare X and y
    X = data.drop(columns=[target_col], errors="ignore").select_dtypes(include=["number"])
    y = data[target_col].values.ravel()

    # Normalize
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)

    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).ravel()

    # Train-test split (no shuffle for time series)
    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_scaled, test_size=test_size, random_state=random_state, shuffle=False
    )

    # RFE with RandomForest
    model = RandomForestRegressor(n_estimators=100, random_state=random_state)
    rfe = RFE(model, n_features_to_select=n_features)
    rfe.fit(X_train, y_train)

    selected_features = np.array(X.columns)[rfe.support_]
    return selected_features.tolist()

# %%
def train_lstm_model(data, selected_features, time_steps=90, test_size=0.2, epochs=100, batch_size=32, learning_rate=0.001):


    X_raw = data[selected_features].values
    target_col = next((col for col in data.columns if "Target" in col), None)
    if target_col is None:
        raise KeyError("Could not find 'Target' in data. Check available columns.")


    # Extract features and target
    y_raw = data[target_col].values.reshape(-1, 1)

    # Normalize features
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X_raw)

    # Normalize target variable
    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y_raw.reshape(-1, 1)).ravel()


    # Convert date column if available
    date_col = next((col for col in data.columns if "Date" in col), None)
    if date_col:
        data[date_col] = pd.to_datetime(data[date_col])
        X_seq, y_seq, dates_seq = create_sequences(X_scaled, y_scaled, data[date_col].values, time_steps)
    else:
        raise KeyError("Could not find 'Date' column in data. Check available columns.")



    # Split into training and test sets
    X_train, X_test, y_train, y_test, dates_train, dates_test = train_test_split(
        X_seq, y_seq, dates_seq, test_size=test_size, random_state=42, shuffle=False
    )

    # Define LSTM model
    model = Sequential([
        Input(shape=(time_steps,  len(selected_features))),
        LSTM(64, return_sequences=True, activation='tanh'),
        LSTM(32, return_sequences=False, activation='tanh'),
        Dropout(0.2),
        Dense(1)
    ])

    # Compile model
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    # Early Stopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1)

    # Train model
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, y_test),
        verbose=1,
        callbacks=[early_stop]
    )

    # Generate predictions
    y_pred = model.predict(X_test)



    return model, y_pred, y_test, scaler_X, scaler_y, dates_test

# %%
def run_trading_strategy(y_pred_actual, y_test_actual, threshold=0.005, initial_capital=1000):
    """
    Executes a long/short trading strategy based on predicted vs. actual prices,
    only trading when the predicted change exceeds the specified threshold.

    Parameters:
        y_pred_actual (np.ndarray): Model's predicted prices (scaled back).
        y_test_actual (np.ndarray): Actual prices (scaled back).
        threshold (float): Minimum predicted change to trigger a trade (default: 0.005 = 0.5%).
        initial_capital (float): Starting capital (default: $1000).

    Returns:
        portfolio (list): Capital progression over time.
        final_return (float): Percentage return on the strategy.
        accuracy (float): Correct trend prediction accuracy.
        total_trades (int): Total number of trades made.
    """
    capital = initial_capital
    portfolio = []
    correct_trend_preds = 0
    total_trades = 0

    for i in range(1, len(y_pred_actual)):
        pred_today = y_pred_actual[i - 1][0]
        pred_tomorrow = y_pred_actual[i][0]
        price_today = y_test_actual[i - 1][0]
        price_tomorrow = y_test_actual[i][0]

        predicted_change = (pred_tomorrow - pred_today) / pred_today

        if abs(predicted_change) >= threshold:
            trade_amount = capital

            if predicted_change > 0:
                # Long position
                shares = trade_amount / price_today
                capital = shares * price_tomorrow

                if price_tomorrow > price_today:
                    correct_trend_preds += 1

            else:
                # Short position
                shares = trade_amount / price_today
                capital += (price_today - price_tomorrow) * shares

                if price_tomorrow < price_today:
                    correct_trend_preds += 1

            total_trades += 1

        portfolio.append(capital)

    final_return = (capital - initial_capital) / initial_capital * 100
    accuracy = (correct_trend_preds / total_trades * 100) if total_trades else 0

    return portfolio, final_return, accuracy, total_trades

# %%
main_ticker = "^FTSE"
tickers = ["HSBA.L", "AZN.L", "ULVR.L", "BP.L", "^IRX", "^VIX", "^TNX"]
TRAIN_START = "2015-01-01"
TRAIN_END = "2025-02-01"

# Get processed data
data = prepare_data(main_ticker, tickers, TRAIN_START, TRAIN_END)
selected_features = select_top_features_rfe(data,10)
print(f"Selected Features: {selected_features}")
model, y_pred, y_test, scaler_X, scaler_y,  dates_test = train_lstm_model(data, selected_features)

y_test_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))

y_pred_actual = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual))
mae_percentage = mean_absolute_percentage_error(y_test_actual, y_pred_actual)
# Out:
# [*********************100%***********************]  7 of 7 completed
# [*********************100%***********************]  1 of 1 completed
# Selected Features: ['Close_^FTSE', 'High_^FTSE', 'Low_^FTSE', 'Volume_^FTSE', 'Target_', 'BP.L_', '^IRX_', 'SMA50_', 'EMA26_', 'MACD_']
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 0.0487 - val_loss: 0.0029
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0045 - val_loss: 0.0011
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 0.0036 - val_loss: 8.7377e-04
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0035 - val_loss: 0.0010
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0035 - val_loss: 8.4093e-04
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0037 - val_loss: 7.8230e-04
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0034 - val_loss: 8.4021e-04
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0030 - val_loss: 8.2921e-04
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0030 - val_loss: 6.7441e-04
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0028 - val_loss: 7.6165e-04
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0026 - val_loss: 7.1135e-04
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 0.0028 - val_loss: 7.0940e-04
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.0026 - val_loss: 7.1293e-04
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 94ms/step - loss: 0.0026 - val_loss: 7.2738e-04
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 24/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 25/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 26/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0025 - val_loss: 8.3962e-04
# Epoch 27/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0024 - val_loss: 6.2581e-04
# Epoch 28/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0021 - val_loss: 6.1012e-04
# Epoch 29/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0020 - val_loss: 6.9014e-04
# Epoch 30/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 31/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0021 - val_loss: 5.9068e-04
# Epoch 32/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0019 - val_loss: 5.4117e-04
# Epoch 33/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0018 - val_loss: 5.0196e-04
# Epoch 34/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0018 - val_loss: 9.7429e-04
# Epoch 35/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - loss: 0.0017 - val_loss: 7.7848e-04
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0017 - val_loss: 6.0816e-04
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0019 - val_loss: 5.3578e-04
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0014 - val_loss: 5.5157e-04
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - loss: 0.0017 - val_loss: 5.3105e-04
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0015 - val_loss: 5.2656e-04
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0016 - val_loss: 8.7221e-04
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0014 - val_loss: 5.4724e-04
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0013 - val_loss: 5.2801e-04
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0014 - val_loss: 4.7731e-04
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0012 - val_loss: 7.0647e-04
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0013 - val_loss: 7.3677e-04
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0013 - val_loss: 8.1108e-04
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0014 - val_loss: 7.4546e-04
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0013 - val_loss: 4.0693e-04
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - loss: 0.0010 - val_loss: 4.6547e-04
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0012 - val_loss: 5.9847e-04
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0011 - val_loss: 4.0117e-04
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0010 - val_loss: 5.9690e-04
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - loss: 0.0010 - val_loss: 5.5832e-04
# Epoch 58/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 9.2266e-04 - val_loss: 4.4040e-04
# Epoch 59/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 9.5492e-04 - val_loss: 0.0017
# Epoch 60/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - loss: 9.6773e-04 - val_loss: 3.9324e-04
# Epoch 61/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 9.7087e-04 - val_loss: 5.1291e-04
# Epoch 62/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0010 - val_loss: 3.8291e-04
# Epoch 63/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 9.8563e-04 - val_loss: 9.9054e-04
# Epoch 64/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 9.3623e-04 - val_loss: 6.7783e-04
# Epoch 65/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 7.6453e-04 - val_loss: 3.9400e-04
# Epoch 66/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - loss: 8.9859e-04 - val_loss: 0.0011
# Epoch 67/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 9.5390e-04 - val_loss: 4.0841e-04
# Epoch 68/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 8.5048e-04 - val_loss: 4.2991e-04
# Epoch 69/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 8.2424e-04 - val_loss: 4.0973e-04
# Epoch 70/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 7.4825e-04 - val_loss: 0.0012
# Epoch 71/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 8.7862e-04 - val_loss: 4.8773e-04
# Epoch 72/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 8.2153e-04 - val_loss: 9.3009e-04
# Epoch 73/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.4322e-04 - val_loss: 4.7886e-04
# Epoch 74/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 7.0443e-04 - val_loss: 0.0013
# Epoch 75/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 7.6522e-04 - val_loss: 8.9724e-04
# Epoch 76/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 7.8283e-04 - val_loss: 4.3577e-04
# Epoch 77/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 6.8532e-04 - val_loss: 6.5704e-04
# Epoch 78/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 7.0345e-04 - val_loss: 3.4909e-04
# Epoch 79/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 6.8046e-04 - val_loss: 5.0327e-04
# Epoch 80/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 6.8605e-04 - val_loss: 6.3201e-04
# Epoch 81/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 6.7444e-04 - val_loss: 3.9497e-04
# Epoch 82/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 7.1239e-04 - val_loss: 4.6910e-04
# Epoch 83/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - loss: 6.5267e-04 - val_loss: 3.6038e-04
# Epoch 84/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 6.4245e-04 - val_loss: 3.9091e-04
# Epoch 85/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 6.9793e-04 - val_loss: 4.6248e-04
# Epoch 86/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 6.9762e-04 - val_loss: 5.8113e-04
# Epoch 87/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 7.0788e-04 - val_loss: 3.5377e-04
# Epoch 88/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 6.3263e-04 - val_loss: 3.8457e-04
# Epoch 89/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - loss: 7.2467e-04 - val_loss: 3.7281e-04
# Epoch 90/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 5.8091e-04 - val_loss: 7.2696e-04
# Epoch 91/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 5.9188e-04 - val_loss: 3.7747e-04
# Epoch 92/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 5.7888e-04 - val_loss: 4.9711e-04
# Epoch 93/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 6.2779e-04 - val_loss: 4.9659e-04
# Epoch 94/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 6.8351e-04 - val_loss: 7.1120e-04
# Epoch 95/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 6.1056e-04 - val_loss: 9.7655e-04
# Epoch 96/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - loss: 5.7920e-04 - val_loss: 3.7233e-04
# Epoch 97/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 6.0289e-04 - val_loss: 4.8325e-04
# Epoch 98/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 6.2955e-04 - val_loss: 4.2810e-04
# Epoch 98: early stopping
# Restoring model weights from the end of the best epoch: 78.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step

# %%
plt.figure(figsize=(14, 7))
plt.plot(dates_test, y_test_actual, label="Actual Adj Close", color="blue")
plt.plot(dates_test, y_pred_actual, label="Predicted Adj Close", color="red", linestyle="dashed")
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.xlabel("Year")
plt.ylabel("Adjusted Close Price")
plt.title("S&P500 Adjusted Close Price Prediction Over Time")
plt.legend()
plt.grid()
plt.show()

print(f"Mean Percentage Error: {mae_percentage}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Mean Percentage Error: 0.00667578523605728
# 🔹 Root Mean Squared Error (RMSE): 68.7591

# %%
portfolio, final_return, accuracy, trades = run_trading_strategy(y_pred_actual, y_test_actual)

print(f" Final Return: {final_return:.2f}%")
print(f" Accuracy: {accuracy:.2f}%")
print(f" Trades Made: {trades}")

plt.figure(figsize=(14, 7))
portfolio_padded = np.insert(portfolio, 0, np.nan)  # or 100.0 as starting capital
plt.plot(dates_test, portfolio_padded, label="Portfolio Value", color="green")

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.title("Trading Strategy Portfolio Over Time")
plt.xlabel("Year")
plt.ylabel("Capital ($)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#  Final Return: 8.02%
#  Accuracy: 50.00%
#  Trades Made: 128

# %%
## section for n=13


selected_features2 = select_top_features_rfe(data,13)
print(f"Selected Features: {selected_features2}")
model, y_pred, y_test, scaler_X, scaler_y,  dates_test = train_lstm_model(data, selected_features2)

mae_scaled = mean_absolute_error(y_test, y_pred)

y_test_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))

y_pred_actual2 = scaler_y.inverse_transform(y_pred.reshape(-1, 1))
rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual2))
mae_percentage = mean_absolute_percentage_error(y_test_actual, y_pred_actual2)
# Out:
# Selected Features: ['Close_^FTSE', 'High_^FTSE', 'Low_^FTSE', 'Volume_^FTSE', 'Target_', 'HSBA.L_', 'AZN.L_', 'BP.L_', '^IRX_', 'SMA50_', 'RSI_', 'EMA26_', 'MACD_']
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 0.1189 - val_loss: 0.0068
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.0059 - val_loss: 0.0039
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.0050 - val_loss: 0.0013
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0044 - val_loss: 0.0022
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0038 - val_loss: 9.1957e-04
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0034 - val_loss: 9.3515e-04
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0030 - val_loss: 9.5841e-04
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0032 - val_loss: 9.3248e-04
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - loss: 0.0033 - val_loss: 8.5406e-04
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0031 - val_loss: 7.5834e-04
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0030 - val_loss: 9.4056e-04
# Epoch 24/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0032 - val_loss: 8.8197e-04
# Epoch 25/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - loss: 0.0031 - val_loss: 9.4159e-04
# Epoch 26/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 27/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0026 - val_loss: 8.5945e-04
# Epoch 28/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 29/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0025 - val_loss: 8.6988e-04
# Epoch 30/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.0026 - val_loss: 7.1331e-04
# Epoch 31/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 32/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 33/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0023 - val_loss: 9.6941e-04
# Epoch 34/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0024 - val_loss: 6.2867e-04
# Epoch 35/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 0.0020 - val_loss: 6.9992e-04
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0020 - val_loss: 6.0609e-04
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0022 - val_loss: 7.8912e-04
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0021 - val_loss: 6.2216e-04
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0019 - val_loss: 7.2145e-04
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0018 - val_loss: 8.6345e-04
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - loss: 0.0018 - val_loss: 5.7309e-04
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 0.0018 - val_loss: 6.7915e-04
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0018 - val_loss: 5.6393e-04
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0016 - val_loss: 5.3863e-04
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0017 - val_loss: 8.9368e-04
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.0018 - val_loss: 5.5637e-04
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0016 - val_loss: 8.7066e-04
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0016 - val_loss: 8.0484e-04
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0014 - val_loss: 5.9404e-04
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0014 - val_loss: 6.0408e-04
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0013 - val_loss: 7.6091e-04
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 0.0014 - val_loss: 6.3464e-04
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0013 - val_loss: 6.3474e-04
# Epoch 58/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0013 - val_loss: 5.3946e-04
# Epoch 59/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0013 - val_loss: 6.4388e-04
# Epoch 60/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0013 - val_loss: 7.8966e-04
# Epoch 61/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0012 - val_loss: 5.4529e-04
# Epoch 62/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0011 - val_loss: 5.6104e-04
# Epoch 63/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0012 - val_loss: 6.0648e-04
# Epoch 64/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0013 - val_loss: 7.1311e-04
# Epoch 65/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0011 - val_loss: 5.9990e-04
# Epoch 66/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0012 - val_loss: 5.3465e-04
# Epoch 67/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.0010 - val_loss: 6.4667e-04
# Epoch 68/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 69/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0011 - val_loss: 4.8876e-04
# Epoch 70/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0011 - val_loss: 5.5084e-04
# Epoch 71/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 9.1689e-04 - val_loss: 4.9781e-04
# Epoch 72/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 9.2532e-04 - val_loss: 5.8556e-04
# Epoch 73/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 9.3785e-04 - val_loss: 5.0109e-04
# Epoch 74/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 9.0697e-04 - val_loss: 5.3298e-04
# Epoch 75/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 8.8459e-04 - val_loss: 7.3805e-04
# Epoch 76/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 9.1976e-04 - val_loss: 7.8358e-04
# Epoch 77/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 9.2983e-04 - val_loss: 4.8433e-04
# Epoch 78/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 9.3975e-04 - val_loss: 7.3807e-04
# Epoch 79/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.4889e-04 - val_loss: 4.5723e-04
# Epoch 80/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 8.9305e-04 - val_loss: 4.8235e-04
# Epoch 81/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 8.5559e-04 - val_loss: 7.1657e-04
# Epoch 82/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.1952e-04 - val_loss: 5.5858e-04
# Epoch 83/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 8.5335e-04 - val_loss: 3.8511e-04
# Epoch 84/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 8.1475e-04 - val_loss: 6.7343e-04
# Epoch 85/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 8.1552e-04 - val_loss: 4.1390e-04
# Epoch 86/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 7.3107e-04 - val_loss: 3.9184e-04
# Epoch 87/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - loss: 8.2304e-04 - val_loss: 7.3759e-04
# Epoch 88/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - loss: 7.5656e-04 - val_loss: 4.5686e-04
# Epoch 89/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 6.7239e-04 - val_loss: 4.1666e-04
# Epoch 90/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 7.0475e-04 - val_loss: 4.5966e-04
# Epoch 91/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 6.6151e-04 - val_loss: 6.1733e-04
# Epoch 92/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 7.4769e-04 - val_loss: 0.0011
# Epoch 93/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 7.7042e-04 - val_loss: 0.0012
# Epoch 94/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 7.5854e-04 - val_loss: 4.6042e-04
# Epoch 95/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 7.3469e-04 - val_loss: 5.2793e-04
# Epoch 96/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 7.6645e-04 - val_loss: 5.1851e-04
# Epoch 97/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 7.1233e-04 - val_loss: 9.3381e-04
# Epoch 98/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 6.7001e-04 - val_loss: 4.4598e-04
# Epoch 99/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 6.6556e-04 - val_loss: 4.1209e-04
# Epoch 100/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 6.2899e-04 - val_loss: 4.3500e-04
# Restoring model weights from the end of the best epoch: 83.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step

# %%
plt.figure(figsize=(14, 7))
plt.plot(dates_test, y_test_actual, label="Actual Adj Close", color="blue")
plt.plot(dates_test, y_pred_actual2, label="Predicted Adj Close", color="red", linestyle="dashed")
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.xlabel("Year")
plt.ylabel("Adjusted Close Price")
plt.title("S&P500 Adjusted Close Price Prediction Over Time")
plt.legend()
plt.grid()
plt.show()

print(f"Mean Percentage Error: {mae_percentage}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Mean Percentage Error: 0.007068763221542512
# 🔹 Root Mean Squared Error (RMSE): 72.2189

# %%
portfolio, final_return, accuracy, trades = run_trading_strategy(y_pred_actual2, y_test_actual)

print(f" Final Return: {final_return:.2f}%")
print(f" Accuracy: {accuracy:.2f}%")
print(f" Trades Made: {trades}")

plt.figure(figsize=(14, 7))
portfolio_padded = np.insert(portfolio, 0, np.nan)  # or 100.0 as starting capital
plt.plot(dates_test, portfolio_padded, label="Portfolio Value", color="green")

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.title("Trading Strategy Portfolio Over Time")
plt.xlabel("Year")
plt.ylabel("Capital ($)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#  Final Return: 11.96%
#  Accuracy: 48.82%
#  Trades Made: 127

# %%
## section for n= 7

selected_features3 = select_top_features_rfe(data,7)
print(f"Selected Features: {selected_features3}")
model, y_pred, y_test, scaler_X, scaler_y,  dates_test = train_lstm_model(data, selected_features2)

mae_scaled = mean_absolute_error(y_test, y_pred)

y_test_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))

y_pred_actual3= scaler_y.inverse_transform(y_pred.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual3))
mae_percentage = mean_absolute_percentage_error(y_test_actual, y_pred_actual3)
# Out:
# Selected Features: ['Close_^FTSE', 'High_^FTSE', 'Low_^FTSE', 'BP.L_', '^IRX_', 'EMA26_', 'MACD_']
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.0807 - val_loss: 0.0065
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0045 - val_loss: 0.0067
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 0.0032 - val_loss: 8.6600e-04
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 24/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 25/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 26/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 27/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0024 - val_loss: 9.5464e-04
# Epoch 28/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 29/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 30/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 31/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 32/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 33/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 34/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0022 - val_loss: 8.7765e-04
# Epoch 35/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0019 - val_loss: 9.3584e-04
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 0.0018 - val_loss: 8.7797e-04
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0020 - val_loss: 7.6161e-04
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.0019 - val_loss: 7.8761e-04
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 0.0017 - val_loss: 7.1489e-04
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0017 - val_loss: 8.3566e-04
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0019 - val_loss: 9.6758e-04
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0014 - val_loss: 7.9219e-04
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 0.0015 - val_loss: 7.1767e-04
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0015 - val_loss: 8.3719e-04
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 0.0014 - val_loss: 7.0319e-04
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0015 - val_loss: 6.9056e-04
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 58/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 59/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 60/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0012 - val_loss: 7.7523e-04
# Epoch 61/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0012 - val_loss: 7.4012e-04
# Epoch 62/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0012 - val_loss: 9.1242e-04
# Epoch 63/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 94ms/step - loss: 9.9134e-04 - val_loss: 8.6679e-04
# Epoch 64/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 65/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0011 - val_loss: 9.8853e-04
# Epoch 66/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 94ms/step - loss: 9.9732e-04 - val_loss: 6.3992e-04
# Epoch 67/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0012 - val_loss: 8.6277e-04
# Epoch 68/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 69/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 9.9039e-04 - val_loss: 0.0014
# Epoch 70/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 0.0010 - val_loss: 6.1129e-04
# Epoch 71/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 9.9974e-04 - val_loss: 0.0013
# Epoch 72/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 9.4971e-04 - val_loss: 9.7934e-04
# Epoch 73/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - loss: 8.8629e-04 - val_loss: 7.0564e-04
# Epoch 74/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - loss: 9.0148e-04 - val_loss: 8.2524e-04
# Epoch 75/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 9.7578e-04 - val_loss: 6.2126e-04
# Epoch 76/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 9.8529e-04 - val_loss: 0.0026
# Epoch 77/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 0.0010 - val_loss: 6.4347e-04
# Epoch 78/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 8.8732e-04 - val_loss: 0.0011
# Epoch 79/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 8.3182e-04 - val_loss: 0.0011
# Epoch 80/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 8.9502e-04 - val_loss: 6.7059e-04
# Epoch 81/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 7.6253e-04 - val_loss: 0.0011
# Epoch 82/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 8.3870e-04 - val_loss: 7.7134e-04
# Epoch 83/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 8.4903e-04 - val_loss: 9.2863e-04
# Epoch 84/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 7.9670e-04 - val_loss: 0.0016
# Epoch 85/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 8.2732e-04 - val_loss: 7.6401e-04
# Epoch 86/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.3839e-04 - val_loss: 5.5471e-04
# Epoch 87/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 7.9207e-04 - val_loss: 6.8521e-04
# Epoch 88/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 7.0972e-04 - val_loss: 6.0788e-04
# Epoch 89/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 7.2714e-04 - val_loss: 5.6128e-04
# Epoch 90/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - loss: 7.5512e-04 - val_loss: 5.8377e-04
# Epoch 91/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 7.0491e-04 - val_loss: 0.0014
# Epoch 92/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 8.2788e-04 - val_loss: 6.7512e-04
# Epoch 93/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - loss: 7.0400e-04 - val_loss: 4.9830e-04
# Epoch 94/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 6.7205e-04 - val_loss: 0.0014
# Epoch 95/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 6.7381e-04 - val_loss: 8.6363e-04
# Epoch 96/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 7.5504e-04 - val_loss: 6.5421e-04
# Epoch 97/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 6.3596e-04 - val_loss: 7.7169e-04
# Epoch 98/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - loss: 6.7779e-04 - val_loss: 9.2183e-04
# Epoch 99/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - loss: 8.1073e-04 - val_loss: 4.7104e-04
# Epoch 100/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 6.7090e-04 - val_loss: 9.7065e-04
# Restoring model weights from the end of the best epoch: 99.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step

# %%
plt.figure(figsize=(14, 7))
plt.plot(dates_test, y_test_actual, label="Actual Adj Close", color="blue")
plt.plot(dates_test, y_pred_actual, label="Predicted Adj Close", color="red", linestyle="dashed")
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.xlabel("Year")
plt.ylabel("Adjusted Close Price")
plt.title("S&P500 Adjusted Close Price Prediction Over Time")
plt.legend()
plt.grid()
plt.show()

print(f"Mean Percentage Error: {mae_percentage}")
print(f"🔹 Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Mean Percentage Error: 0.007839766057082448
# 🔹 Root Mean Squared Error (RMSE): 79.8711

# %%
portfolio, final_return, accuracy, trades = run_trading_strategy(y_pred_actual3, y_test_actual)

print(f" Final Return: {final_return:.2f}%")
print(f" Accuracy: {accuracy:.2f}%")
print(f" Trades Made: {trades}")

plt.figure(figsize=(14, 7))
portfolio_padded = np.insert(portfolio, 0, np.nan)  # or 100.0 as starting capital
plt.plot(dates_test, portfolio_padded, label="Portfolio Value", color="green")

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.title("Trading Strategy Portfolio Over Time")
plt.xlabel("Year")
plt.ylabel("Capital ($)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#  Final Return: 2.56%
#  Accuracy: 47.57%
#  Trades Made: 103
